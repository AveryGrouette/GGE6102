# %% [markdown]
# Code for Calculating the Height Solution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Avery\OneDrive\Documents\GitHub\GGE6102\HeightSolution.csv')

df.head()
# Out:
#    Time        DKF     GNSS    F180
# 0   1.0 -15.601711 -16.2781 -20.546
# 1   2.0 -15.615711 -16.2921 -20.546
# 2   3.0 -15.708111 -16.3845 -20.546
# 3   4.0 -15.938011 -16.6144 -20.547
# 4   5.0 -16.117411 -16.7938 -20.548

# %%
plt.plot(df.iloc[:,0], df.iloc[:,1], label = "Direct Kalman Filter")
plt.plot(df.iloc[:,0], df.iloc[:,2], label = "GNSS", linewidth = 1)
plt.plot(df.iloc[:,0], df.iloc[:,3], label = "Unscented Kalman Filter")
plt.legend()
plt.show()

# %%
df.min()
# Out:
# Time     1.000000
# DKF    -64.016589
# GNSS   -64.692700
# F180   -22.734000
# dtype: float64

# %%
df.max()
# Out:
# Time    3446.000000
# DKF       18.342834
# GNSS      17.672000
# F180     -19.617000
# dtype: float64
